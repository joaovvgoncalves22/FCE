# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovvgoncalves22/FCE/blob/main/Importar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/joaovvgoncalves22/FCE.git -qq
# Out:
# fatal: destination path 'FCE' already exists and is not an empty directory.

# %%
from FCE.Prova import (
    ParametrosBioreator,
    Bioreator_modelo,
    Simula_Bioreator
)
